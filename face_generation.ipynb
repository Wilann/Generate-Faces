# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip
# Out:
# unzip:  cannot find or open processed_celeba_small.zip, processed_celeba_small.zip.zip or processed_celeba_small.zip.ZIP.

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torch.utils.data import DataLoader 
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose([transforms.Resize(image_size), # resize to image_size x image_size 
                                    transforms.ToTensor()])
    
    # Dataset 
    dataset = datasets.ImageFolder(data_dir, transform)
    
    # Dataloader 
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
    
    return data_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    
    # Assume x is scaled to (0, 1)
    min_val, max_val = feature_range
    x = x * (max_val - min_val) + min_val
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9686)
# Max:  tensor(0.9216)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        self.conv_dim = conv_dim 
        
        # Convolutional layers 
        self.conv1 = nn.Conv2d(3, conv_dim, kernel_size=4, stride=2, padding=1, bias=False)
        self.conv2 = nn.Conv2d(conv_dim, conv_dim*2, kernel_size=4, stride=2, padding=1, bias=False)
        self.conv3 = nn.Conv2d(conv_dim*2, conv_dim*4, kernel_size=4, stride=2, padding=1, bias=False)
        
        # Linear layer 
        self.fc = nn.Linear(conv_dim*4*4*4, 1)
        
        # Batch normalization
        self.batch_norm1 = nn.BatchNorm2d(conv_dim)
        self.batch_norm2 = nn.BatchNorm2d(conv_dim*2)
        self.batch_norm3 = nn.BatchNorm2d(conv_dim*4)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        
        # Hidden layers
        x = F.leaky_relu(self.conv1(x), 0.2) # 32x32x3 --> 16x16x(conv_dim)
        x = self.batch_norm1(x)
        
        x = F.leaky_relu(self.conv2(x), 0.2) # 16x16x(conv_dim) --> 8x8x(conv_dim*2)
        x = self.batch_norm2(x)
        
        x = F.leaky_relu(self.conv3(x), 0.2) # 8x8x(conv_dim*2) --> 4x4x(conv_dim*4)
        x = self.batch_norm3(x)
        
        # Flatten 
        # (conv_dim*4) from conv3 output depth 
        # (*4*4) from conv3 width and height 
        x = x.view(-1, self.conv_dim*4*4*4) # 4x4x(conv_dim*4) --> (conv_dim*4*4*4)
        
        # Final layer 
        x = self.fc(x) # (conv_dim*4*4*4) --> 1
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        
        self.conv_dim = conv_dim

        # Transpose convolutional layers 
        self.transpose_conv1 = nn.ConvTranspose2d(conv_dim*4, conv_dim*2, kernel_size=4, stride=2, padding=1, bias=False)
        self.transpose_conv2 = nn.ConvTranspose2d(conv_dim*2, conv_dim, kernel_size=4, stride=2, padding=1, bias=False)
        self.transpose_conv3 = nn.ConvTranspose2d(conv_dim, 3, kernel_size=4, stride=2, padding=1, bias=False)
        
        # Fully-connected layer 
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)
        
        # Batch normalization layers
        self.batch_norm1 = nn.BatchNorm2d(conv_dim*2)
        self.batch_norm2 = nn.BatchNorm2d(conv_dim)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        
        # Expand 
        # (conv_dim*4) from conv3 output depth 
        # (*4*4) from conv3 width and height 
        x = self.fc(x) # z_size --> (conv_dim*4*4*4)
        
        # Reshape
        x = x.view(-1, self.conv_dim*4, 4, 4) # (conv_dim*4*4*4) --> (conv_dim*4)x4x4
        
        # Hidden layers
        x = self.transpose_conv1(x) # (conv_dim*4)x4x4 --> (conv_dim*2)x8x8
        x = self.batch_norm1(x)
        x = F.relu(x)
        
        x = self.transpose_conv2(x) # (conv_dim*2)x8x8 --> conv_dimx16x16
        x = self.batch_norm2(x)
        x = F.relu(x)
        
        x = self.transpose_conv3(x) # conv_dimx16x16 --> 3x32x32
        x = F.tanh(x)
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like: `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # Apply initial weights to convolutional and linear layers
    if classname.find('Conv') != -1 or classname.find('Linear') != -1:
        m.weight.data.normal_(0, 0.02)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
#   (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
#
# Generator(
#   (transpose_conv1): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (transpose_conv2): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (transpose_conv3): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch_norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU~')
# Out:
# No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    
    batch_size = D_out.size(0)
    
    if train_on_gpu:
        labels = torch.ones(batch_size).cuda()
    else: 
        labels = torch.ones(batch_size)

    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    
    if train_on_gpu:
        labels = torch.zeros(batch_size).cuda()
    else: 
        labels = torch.zeros(batch_size)

    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# Parameters 
lr = 0.0002
beta1 = 0.5
beta2 = 0.999 # default 

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            
            real_images = scale(real_images)
            if train_on_gpu:
                real_images = real_images.cuda()

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train discriminator on real and fake images
            d_optimizer.zero_grad()
            
            # Loss on real images 
            d_real = D(real_images)
            d_real_loss = real_loss(d_real)
            
            # Generate fake images 
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            
            # Loss on fake images 
            d_fake = D(fake_images)
            d_fake_loss = fake_loss(d_fake)
            
            # Sum losses, calculate weights, back propagation
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            # Train generator on real and fake images 
            
            # Generate fake images 
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            
            # Compute the discriminator losses on fake images USING FLIPPED LABELS using REAL LOSS 
            # In other words, compare fake images with 1s 
            d_fake = D(fake_images)
            g_loss = real_loss(d_fake)
            
            # Calculate weights, backpropagation 
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        # After each epoch, generate and save sample, fake images
        
        # for generating samples
        G.eval() 
        
        samples_z = G(fixed_z)
        samples.append(samples_z)
        
        # back to training mode
        G.train() 

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# Number of epochs 
n_epochs = 30

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   30] | d_loss: 1.5671 | g_loss: 1.1941
# Epoch [    1/   30] | d_loss: 0.5611 | g_loss: 3.1995
# Epoch [    1/   30] | d_loss: 0.4936 | g_loss: 4.8524
# Epoch [    1/   30] | d_loss: 0.4753 | g_loss: 4.7304
# Epoch [    1/   30] | d_loss: 0.5089 | g_loss: 5.1642
# Epoch [    1/   30] | d_loss: 0.3703 | g_loss: 5.2279
# Epoch [    1/   30] | d_loss: 0.2225 | g_loss: 5.2275
# Epoch [    1/   30] | d_loss: 0.1399 | g_loss: 5.0398
# Epoch [    1/   30] | d_loss: 0.1171 | g_loss: 5.0857
# Epoch [    1/   30] | d_loss: 0.1183 | g_loss: 5.3032
# Epoch [    1/   30] | d_loss: 0.0923 | g_loss: 5.3138
# Epoch [    1/   30] | d_loss: 0.0742 | g_loss: 5.5532
# Epoch [    1/   30] | d_loss: 0.0676 | g_loss: 5.2746
# Epoch [    1/   30] | d_loss: 0.0802 | g_loss: 5.2350
# Epoch [    1/   30] | d_loss: 0.0610 | g_loss: 5.8307
# Epoch [    2/   30] | d_loss: 0.0647 | g_loss: 5.7937
# Epoch [    2/   30] | d_loss: 0.0288 | g_loss: 5.7894
# Epoch [    2/   30] | d_loss: 0.0248 | g_loss: 5.6121
# Epoch [    2/   30] | d_loss: 0.0257 | g_loss: 5.6524
# Epoch [    2/   30] | d_loss: 0.0155 | g_loss: 5.7838
# Epoch [    2/   30] | d_loss: 0.0250 | g_loss: 5.6779
# Epoch [    2/   30] | d_loss: 0.0405 | g_loss: 5.6181
# Epoch [    2/   30] | d_loss: 0.0168 | g_loss: 6.0157
# Epoch [    2/   30] | d_loss: 0.0154 | g_loss: 5.7536
# Epoch [    2/   30] | d_loss: 0.0126 | g_loss: 5.9387
# Epoch [    2/   30] | d_loss: 0.0106 | g_loss: 6.1408
# Epoch [    2/   30] | d_loss: 0.0129 | g_loss: 5.5790
# Epoch [    2/   30] | d_loss: 0.0286 | g_loss: 6.5805
# Epoch [    2/   30] | d_loss: 0.0773 | g_loss: 4.6396
# Epoch [    2/   30] | d_loss: 0.1034 | g_loss: 4.8231
# Epoch [    3/   30] | d_loss: 0.0596 | g_loss: 5.2402
# Epoch [    3/   30] | d_loss: 0.0551 | g_loss: 4.9586
# Epoch [    3/   30] | d_loss: 0.0555 | g_loss: 5.5579
# Epoch [    3/   30] | d_loss: 0.0754 | g_loss: 4.7450
# Epoch [    3/   30] | d_loss: 0.1609 | g_loss: 3.9447
# Epoch [    3/   30] | d_loss: 0.2238 | g_loss: 5.7061
# Epoch [    3/   30] | d_loss: 0.2179 | g_loss: 4.8937
# Epoch [    3/   30] | d_loss: 0.2986 | g_loss: 4.4828
# Epoch [    3/   30] | d_loss: 1.3308 | g_loss: 11.8920
# Epoch [    3/   30] | d_loss: 0.1549 | g_loss: 4.5745
# Epoch [    3/   30] | d_loss: 0.2908 | g_loss: 3.4725
# Epoch [    3/   30] | d_loss: 0.5248 | g_loss: 2.8772
# Epoch [    3/   30] | d_loss: 0.3584 | g_loss: 3.6497
# Epoch [    3/   30] | d_loss: 0.4736 | g_loss: 2.7454
# Epoch [    3/   30] | d_loss: 0.3790 | g_loss: 2.2319
# Epoch [    4/   30] | d_loss: 0.4931 | g_loss: 2.2441
# Epoch [    4/   30] | d_loss: 0.4774 | g_loss: 2.5436
# Epoch [    4/   30] | d_loss: 0.6164 | g_loss: 4.0616
# Epoch [    4/   30] | d_loss: 0.5033 | g_loss: 2.8239
# Epoch [    4/   30] | d_loss: 0.5591 | g_loss: 2.0795
# Epoch [    4/   30] | d_loss: 0.6529 | g_loss: 1.9871
# Epoch [    4/   30] | d_loss: 0.6803 | g_loss: 1.6168
# Epoch [    4/   30] | d_loss: 0.5559 | g_loss: 2.9706
# Epoch [    4/   30] | d_loss: 1.0264 | g_loss: 0.6987
# Epoch [    4/   30] | d_loss: 0.5308 | g_loss: 2.3594
# Epoch [    4/   30] | d_loss: 0.7607 | g_loss: 2.3309
# Epoch [    4/   30] | d_loss: 1.0724 | g_loss: 3.1049
# Epoch [    4/   30] | d_loss: 0.8151 | g_loss: 2.6822
# Epoch [    4/   30] | d_loss: 0.7445 | g_loss: 1.5092
# Epoch [    4/   30] | d_loss: 0.6395 | g_loss: 1.7371
# Epoch [    5/   30] | d_loss: 0.6504 | g_loss: 2.0302
# Epoch [    5/   30] | d_loss: 0.6784 | g_loss: 1.9226
# Epoch [    5/   30] | d_loss: 0.8474 | g_loss: 2.5203
# Epoch [    5/   30] | d_loss: 0.7601 | g_loss: 1.2308
# Epoch [    5/   30] | d_loss: 0.7442 | g_loss: 1.3439
# Epoch [    5/   30] | d_loss: 0.6103 | g_loss: 2.3143
# Epoch [    5/   30] | d_loss: 1.1156 | g_loss: 0.9519
# Epoch [    5/   30] | d_loss: 0.7699 | g_loss: 1.3987
# Epoch [    5/   30] | d_loss: 0.9314 | g_loss: 2.4353
# Epoch [    5/   30] | d_loss: 0.5369 | g_loss: 1.8405
# Epoch [    5/   30] | d_loss: 0.6906 | g_loss: 1.5318
# Epoch [    5/   30] | d_loss: 0.5988 | g_loss: 1.6581
# Epoch [    5/   30] | d_loss: 0.9461 | g_loss: 2.3513
# Epoch [    5/   30] | d_loss: 0.5901 | g_loss: 1.7994
# Epoch [    5/   30] | d_loss: 0.6881 | g_loss: 2.0981
# Epoch [    6/   30] | d_loss: 0.6313 | g_loss: 1.5947
# Epoch [    6/   30] | d_loss: 0.6539 | g_loss: 1.8026
# Epoch [    6/   30] | d_loss: 1.1202 | g_loss: 2.2365
# Epoch [    6/   30] | d_loss: 0.5726 | g_loss: 1.9829
# Epoch [    6/   30] | d_loss: 0.5859 | g_loss: 1.6300
# Epoch [    6/   30] | d_loss: 0.4615 | g_loss: 1.9781
# Epoch [    6/   30] | d_loss: 0.9437 | g_loss: 2.0746
# Epoch [    6/   30] | d_loss: 0.7402 | g_loss: 2.2123
# Epoch [    6/   30] | d_loss: 0.5724 | g_loss: 1.9978
# Epoch [    6/   30] | d_loss: 0.6730 | g_loss: 1.0963
# Epoch [    6/   30] | d_loss: 0.9163 | g_loss: 1.4247
# Epoch [    6/   30] | d_loss: 1.0633 | g_loss: 0.9901
# Epoch [    6/   30] | d_loss: 0.7144 | g_loss: 2.3119
# Epoch [    6/   30] | d_loss: 1.2292 | g_loss: 1.6279
# Epoch [    6/   30] | d_loss: 0.4946 | g_loss: 2.5098
# Epoch [    7/   30] | d_loss: 0.9074 | g_loss: 1.0009
# Epoch [    7/   30] | d_loss: 0.8281 | g_loss: 2.1688
# Epoch [    7/   30] | d_loss: 0.5796 | g_loss: 1.8896
# Epoch [    7/   30] | d_loss: 0.5415 | g_loss: 2.2341
# Epoch [    7/   30] | d_loss: 1.0955 | g_loss: 1.2339
# Epoch [    7/   30] | d_loss: 0.9032 | g_loss: 1.2759
# Epoch [    7/   30] | d_loss: 0.4201 | g_loss: 1.9430
# Epoch [    7/   30] | d_loss: 1.1659 | g_loss: 2.3125
# Epoch [    7/   30] | d_loss: 1.0303 | g_loss: 0.9637
# Epoch [    7/   30] | d_loss: 0.6455 | g_loss: 2.2228
# Epoch [    7/   30] | d_loss: 1.5138 | g_loss: 0.7140
# Epoch [    7/   30] | d_loss: 0.8944 | g_loss: 1.0099
# Epoch [    7/   30] | d_loss: 0.7765 | g_loss: 2.4810
# Epoch [    7/   30] | d_loss: 0.8830 | g_loss: 1.0918
# Epoch [    7/   30] | d_loss: 1.1115 | g_loss: 0.7388
# Epoch [    8/   30] | d_loss: 0.5275 | g_loss: 2.0344
# Epoch [    8/   30] | d_loss: 1.3018 | g_loss: 2.7340
# Epoch [    8/   30] | d_loss: 0.4720 | g_loss: 1.3313
# Epoch [    8/   30] | d_loss: 1.0786 | g_loss: 1.0563
# Epoch [    8/   30] | d_loss: 0.7782 | g_loss: 1.6773
# Epoch [    8/   30] | d_loss: 0.5734 | g_loss: 2.3356
# Epoch [    8/   30] | d_loss: 0.5677 | g_loss: 1.4985
# Epoch [    8/   30] | d_loss: 0.5420 | g_loss: 2.1763
# Epoch [    8/   30] | d_loss: 0.5271 | g_loss: 1.5472
# Epoch [    8/   30] | d_loss: 0.7569 | g_loss: 1.5731
# Epoch [    8/   30] | d_loss: 0.6911 | g_loss: 2.7930
# Epoch [    8/   30] | d_loss: 0.5821 | g_loss: 1.6088
# Epoch [    8/   30] | d_loss: 0.9518 | g_loss: 1.6431
# Epoch [    8/   30] | d_loss: 0.5179 | g_loss: 2.2437
# Epoch [    8/   30] | d_loss: 1.4045 | g_loss: 1.0986
# Epoch [    9/   30] | d_loss: 1.0098 | g_loss: 3.5440
# Epoch [    9/   30] | d_loss: 0.7440 | g_loss: 1.6704
# Epoch [    9/   30] | d_loss: 0.4814 | g_loss: 1.6187
# Epoch [    9/   30] | d_loss: 0.7430 | g_loss: 2.6705
# Epoch [    9/   30] | d_loss: 0.6137 | g_loss: 0.9165
# Epoch [    9/   30] | d_loss: 0.8614 | g_loss: 1.2042
# Epoch [    9/   30] | d_loss: 0.6098 | g_loss: 2.4374
# Epoch [    9/   30] | d_loss: 0.9213 | g_loss: 2.4849
# Epoch [    9/   30] | d_loss: 0.7746 | g_loss: 0.6873
# Epoch [    9/   30] | d_loss: 0.7692 | g_loss: 0.9689
# Epoch [    9/   30] | d_loss: 0.6508 | g_loss: 2.0618
# Epoch [    9/   30] | d_loss: 0.6204 | g_loss: 1.5664
# Epoch [    9/   30] | d_loss: 0.8118 | g_loss: 1.9796
# Epoch [    9/   30] | d_loss: 0.7657 | g_loss: 1.3368
# Epoch [    9/   30] | d_loss: 0.6313 | g_loss: 1.3819
# Epoch [   10/   30] | d_loss: 0.4516 | g_loss: 1.6196
# Epoch [   10/   30] | d_loss: 0.5657 | g_loss: 3.1108
# Epoch [   10/   30] | d_loss: 0.7323 | g_loss: 1.4037
# Epoch [   10/   30] | d_loss: 1.5690 | g_loss: 0.4650
# Epoch [   10/   30] | d_loss: 0.8403 | g_loss: 2.2115
# Epoch [   10/   30] | d_loss: 0.6433 | g_loss: 3.4691
# Epoch [   10/   30] | d_loss: 0.5615 | g_loss: 1.9357
# Epoch [   10/   30] | d_loss: 1.1536 | g_loss: 2.9720
# Epoch [   10/   30] | d_loss: 0.8079 | g_loss: 2.6054
# Epoch [   10/   30] | d_loss: 0.6093 | g_loss: 1.4512
# Epoch [   10/   30] | d_loss: 0.5244 | g_loss: 1.8022
# Epoch [   10/   30] | d_loss: 1.0517 | g_loss: 2.0849
# Epoch [   10/   30] | d_loss: 0.7140 | g_loss: 2.6506
# Epoch [   10/   30] | d_loss: 0.6677 | g_loss: 0.9798
# Epoch [   10/   30] | d_loss: 0.5366 | g_loss: 2.9701
# Epoch [   11/   30] | d_loss: 0.5131 | g_loss: 2.1128
# Epoch [   11/   30] | d_loss: 0.5620 | g_loss: 2.2233
# Epoch [   11/   30] | d_loss: 0.8469 | g_loss: 1.3156
# Epoch [   11/   30] | d_loss: 0.5607 | g_loss: 1.4017
# Epoch [   11/   30] | d_loss: 0.9993 | g_loss: 1.1672
# Epoch [   11/   30] | d_loss: 0.8064 | g_loss: 2.4848
# Epoch [   11/   30] | d_loss: 0.5594 | g_loss: 2.0590
# Epoch [   11/   30] | d_loss: 0.3959 | g_loss: 1.5752
# Epoch [   11/   30] | d_loss: 0.7051 | g_loss: 1.7337
# Epoch [   11/   30] | d_loss: 1.6027 | g_loss: 0.5145
# Epoch [   11/   30] | d_loss: 0.6824 | g_loss: 2.4269
# Epoch [   11/   30] | d_loss: 0.8583 | g_loss: 1.6994
# Epoch [   11/   30] | d_loss: 0.4328 | g_loss: 2.8728
# Epoch [   11/   30] | d_loss: 1.2672 | g_loss: 0.2785
# Epoch [   11/   30] | d_loss: 0.8604 | g_loss: 2.7021
# Epoch [   12/   30] | d_loss: 1.0368 | g_loss: 4.0797
# Epoch [   12/   30] | d_loss: 0.4410 | g_loss: 2.5668
# Epoch [   12/   30] | d_loss: 0.6014 | g_loss: 1.8525
# Epoch [   12/   30] | d_loss: 0.5082 | g_loss: 1.5970
# Epoch [   12/   30] | d_loss: 0.9130 | g_loss: 2.5958
# Epoch [   12/   30] | d_loss: 0.6047 | g_loss: 1.2304
# Epoch [   12/   30] | d_loss: 0.3976 | g_loss: 2.0905
# Epoch [   12/   30] | d_loss: 0.4968 | g_loss: 1.5037
# Epoch [   12/   30] | d_loss: 0.2954 | g_loss: 1.6242
# Epoch [   12/   30] | d_loss: 0.7399 | g_loss: 0.9948
# Epoch [   12/   30] | d_loss: 1.2113 | g_loss: 4.2605
# Epoch [   12/   30] | d_loss: 0.5747 | g_loss: 2.0703
# Epoch [   12/   30] | d_loss: 0.6631 | g_loss: 2.6203
# Epoch [   12/   30] | d_loss: 0.6026 | g_loss: 1.9520
# Epoch [   12/   30] | d_loss: 0.4319 | g_loss: 2.2449
# Epoch [   13/   30] | d_loss: 0.6314 | g_loss: 2.3050
# Epoch [   13/   30] | d_loss: 0.3918 | g_loss: 2.2282
# Epoch [   13/   30] | d_loss: 0.6968 | g_loss: 1.7642
# Epoch [   13/   30] | d_loss: 0.6359 | g_loss: 1.3418
# Epoch [   13/   30] | d_loss: 0.8095 | g_loss: 1.4217
# Epoch [   13/   30] | d_loss: 0.4940 | g_loss: 2.1517
# Epoch [   13/   30] | d_loss: 0.3555 | g_loss: 1.6069
# Epoch [   13/   30] | d_loss: 0.6526 | g_loss: 1.8618
# Epoch [   13/   30] | d_loss: 0.5060 | g_loss: 1.9704
# Epoch [   13/   30] | d_loss: 0.6094 | g_loss: 1.3182
# Epoch [   13/   30] | d_loss: 0.5168 | g_loss: 1.9578
# Epoch [   13/   30] | d_loss: 0.5838 | g_loss: 3.5851
# Epoch [   13/   30] | d_loss: 0.5508 | g_loss: 1.3651
# Epoch [   13/   30] | d_loss: 1.0336 | g_loss: 1.2486
# Epoch [   13/   30] | d_loss: 0.7007 | g_loss: 3.6840
# Epoch [   14/   30] | d_loss: 0.4936 | g_loss: 2.4583
# Epoch [   14/   30] | d_loss: 0.2795 | g_loss: 2.4464
# Epoch [   14/   30] | d_loss: 0.7209 | g_loss: 1.6548
# Epoch [   14/   30] | d_loss: 0.2339 | g_loss: 3.3855
# Epoch [   14/   30] | d_loss: 0.6058 | g_loss: 1.9764
# Epoch [   14/   30] | d_loss: 0.4902 | g_loss: 1.9847
# Epoch [   14/   30] | d_loss: 0.7018 | g_loss: 2.0175
# Epoch [   14/   30] | d_loss: 0.3550 | g_loss: 2.0288
# Epoch [   14/   30] | d_loss: 0.6800 | g_loss: 3.0841
# Epoch [   14/   30] | d_loss: 0.8519 | g_loss: 2.6379
# Epoch [   14/   30] | d_loss: 0.3131 | g_loss: 3.4552
# Epoch [   14/   30] | d_loss: 0.4267 | g_loss: 1.7170
# Epoch [   14/   30] | d_loss: 0.3407 | g_loss: 2.4180
# Epoch [   14/   30] | d_loss: 0.3355 | g_loss: 1.9369
# Epoch [   14/   30] | d_loss: 0.9846 | g_loss: 1.9943
# Epoch [   15/   30] | d_loss: 1.0837 | g_loss: 1.3594
# Epoch [   15/   30] | d_loss: 0.9497 | g_loss: 0.6332
# Epoch [   15/   30] | d_loss: 0.4681 | g_loss: 2.1998
# Epoch [   15/   30] | d_loss: 0.2971 | g_loss: 1.3862
# Epoch [   15/   30] | d_loss: 0.5963 | g_loss: 1.3317
# Epoch [   15/   30] | d_loss: 0.5299 | g_loss: 2.8891
# Epoch [   15/   30] | d_loss: 1.0000 | g_loss: 2.9249
# Epoch [   15/   30] | d_loss: 0.3311 | g_loss: 2.3130
# Epoch [   15/   30] | d_loss: 0.5789 | g_loss: 2.3922
# Epoch [   15/   30] | d_loss: 0.5822 | g_loss: 2.6626
# Epoch [   15/   30] | d_loss: 0.4314 | g_loss: 2.9927
# Epoch [   15/   30] | d_loss: 0.6959 | g_loss: 1.1084
# Epoch [   15/   30] | d_loss: 0.6257 | g_loss: 2.7812
# Epoch [   15/   30] | d_loss: 0.3246 | g_loss: 2.0123
# Epoch [   15/   30] | d_loss: 0.4736 | g_loss: 2.9118
# Epoch [   16/   30] | d_loss: 0.7322 | g_loss: 2.1026
# Epoch [   16/   30] | d_loss: 0.7317 | g_loss: 1.4687
# Epoch [   16/   30] | d_loss: 2.1368 | g_loss: 3.6557
# Epoch [   16/   30] | d_loss: 0.4356 | g_loss: 1.8811
# Epoch [   16/   30] | d_loss: 0.3391 | g_loss: 2.5384
# Epoch [   16/   30] | d_loss: 0.3455 | g_loss: 2.8910
# Epoch [   16/   30] | d_loss: 0.8482 | g_loss: 1.3959
# Epoch [   16/   30] | d_loss: 0.3889 | g_loss: 1.6049
# Epoch [   16/   30] | d_loss: 0.6554 | g_loss: 1.3959
# Epoch [   16/   30] | d_loss: 0.7480 | g_loss: 3.7486
# Epoch [   16/   30] | d_loss: 1.1238 | g_loss: 2.8169
# Epoch [   16/   30] | d_loss: 0.5862 | g_loss: 1.5556
# Epoch [   16/   30] | d_loss: 0.4693 | g_loss: 2.6745
# Epoch [   16/   30] | d_loss: 0.6914 | g_loss: 1.1032
# Epoch [   16/   30] | d_loss: 0.6609 | g_loss: 1.9431
# Epoch [   17/   30] | d_loss: 0.2985 | g_loss: 1.2506
# Epoch [   17/   30] | d_loss: 0.2523 | g_loss: 3.8682
# Epoch [   17/   30] | d_loss: 1.2091 | g_loss: 3.2921
# Epoch [   17/   30] | d_loss: 0.6643 | g_loss: 2.8779
# Epoch [   17/   30] | d_loss: 0.8404 | g_loss: 2.6735
# Epoch [   17/   30] | d_loss: 0.9806 | g_loss: 3.7658
# Epoch [   17/   30] | d_loss: 0.3316 | g_loss: 2.8276
# Epoch [   17/   30] | d_loss: 0.7754 | g_loss: 1.6525
# Epoch [   17/   30] | d_loss: 0.3254 | g_loss: 3.1681
# Epoch [   17/   30] | d_loss: 0.4394 | g_loss: 2.9844
# Epoch [   17/   30] | d_loss: 0.1797 | g_loss: 2.9442
# Epoch [   17/   30] | d_loss: 0.4358 | g_loss: 3.1165
# Epoch [   17/   30] | d_loss: 0.5999 | g_loss: 1.2810
# Epoch [   17/   30] | d_loss: 1.5983 | g_loss: 3.6855
# Epoch [   17/   30] | d_loss: 0.3247 | g_loss: 2.7688
# Epoch [   18/   30] | d_loss: 0.5740 | g_loss: 3.2651
# Epoch [   18/   30] | d_loss: 0.2716 | g_loss: 1.3332
# Epoch [   18/   30] | d_loss: 0.2591 | g_loss: 3.6963
# Epoch [   18/   30] | d_loss: 0.3265 | g_loss: 3.0075
# Epoch [   18/   30] | d_loss: 0.5237 | g_loss: 1.9408
# Epoch [   18/   30] | d_loss: 0.8802 | g_loss: 1.1918
# Epoch [   18/   30] | d_loss: 0.7425 | g_loss: 3.2289
# Epoch [   18/   30] | d_loss: 0.3557 | g_loss: 3.2831
# Epoch [   18/   30] | d_loss: 0.7004 | g_loss: 1.4854
# Epoch [   18/   30] | d_loss: 0.3707 | g_loss: 3.0786
# Epoch [   18/   30] | d_loss: 0.4820 | g_loss: 2.1588
# Epoch [   18/   30] | d_loss: 0.3730 | g_loss: 2.6852
# Epoch [   18/   30] | d_loss: 0.5992 | g_loss: 4.1283
# Epoch [   18/   30] | d_loss: 0.2834 | g_loss: 2.2893
# Epoch [   18/   30] | d_loss: 0.5539 | g_loss: 2.7707
# Epoch [   19/   30] | d_loss: 0.5453 | g_loss: 2.8383
# Epoch [   19/   30] | d_loss: 0.2905 | g_loss: 2.6612
# Epoch [   19/   30] | d_loss: 0.6816 | g_loss: 4.9996
# Epoch [   19/   30] | d_loss: 0.4579 | g_loss: 0.5666
# Epoch [   19/   30] | d_loss: 0.3066 | g_loss: 1.4549
# Epoch [   19/   30] | d_loss: 0.2718 | g_loss: 2.9761
# Epoch [   19/   30] | d_loss: 0.3499 | g_loss: 2.7368
# Epoch [   19/   30] | d_loss: 0.2389 | g_loss: 3.6247
# Epoch [   19/   30] | d_loss: 0.3876 | g_loss: 2.9220
# Epoch [   19/   30] | d_loss: 0.4929 | g_loss: 4.0048
# Epoch [   19/   30] | d_loss: 0.5758 | g_loss: 3.6412
# Epoch [   19/   30] | d_loss: 0.4649 | g_loss: 3.4237
# Epoch [   19/   30] | d_loss: 0.3453 | g_loss: 4.3434
# Epoch [   19/   30] | d_loss: 0.4084 | g_loss: 2.8189
# Epoch [   19/   30] | d_loss: 0.4160 | g_loss: 3.6009
# Epoch [   20/   30] | d_loss: 0.4002 | g_loss: 2.9246
# Epoch [   20/   30] | d_loss: 0.3349 | g_loss: 2.9988
# Epoch [   20/   30] | d_loss: 0.7035 | g_loss: 1.8894
# Epoch [   20/   30] | d_loss: 0.6271 | g_loss: 2.9358
# Epoch [   20/   30] | d_loss: 0.6043 | g_loss: 2.6036
# Epoch [   20/   30] | d_loss: 0.6396 | g_loss: 3.8272
# Epoch [   20/   30] | d_loss: 0.2876 | g_loss: 2.9734
# Epoch [   20/   30] | d_loss: 0.1710 | g_loss: 3.0004
# Epoch [   20/   30] | d_loss: 0.5927 | g_loss: 4.2926
# Epoch [   20/   30] | d_loss: 0.2373 | g_loss: 2.1200
# Epoch [   20/   30] | d_loss: 0.4397 | g_loss: 1.2342
# Epoch [   20/   30] | d_loss: 0.3668 | g_loss: 2.7528
# Epoch [   20/   30] | d_loss: 0.3109 | g_loss: 2.7452
# Epoch [   20/   30] | d_loss: 0.2832 | g_loss: 2.6351
# Epoch [   20/   30] | d_loss: 0.4737 | g_loss: 2.6904
# Epoch [   21/   30] | d_loss: 0.3118 | g_loss: 2.8894
# Epoch [   21/   30] | d_loss: 0.2431 | g_loss: 2.7816
# Epoch [   21/   30] | d_loss: 0.4011 | g_loss: 2.5561
# Epoch [   21/   30] | d_loss: 0.5410 | g_loss: 1.7409
# Epoch [   21/   30] | d_loss: 0.2584 | g_loss: 2.6923
# Epoch [   21/   30] | d_loss: 0.2227 | g_loss: 2.4098
# Epoch [   21/   30] | d_loss: 0.3864 | g_loss: 3.4238
# Epoch [   21/   30] | d_loss: 0.6802 | g_loss: 5.3605
# Epoch [   21/   30] | d_loss: 0.5688 | g_loss: 2.2868
# Epoch [   21/   30] | d_loss: 0.3040 | g_loss: 2.2936
# Epoch [   21/   30] | d_loss: 0.7913 | g_loss: 2.8332
# Epoch [   21/   30] | d_loss: 0.3749 | g_loss: 2.7787
# Epoch [   21/   30] | d_loss: 0.4353 | g_loss: 1.9198
# Epoch [   21/   30] | d_loss: 0.3943 | g_loss: 3.7109
# Epoch [   21/   30] | d_loss: 0.3307 | g_loss: 2.5834
# Epoch [   22/   30] | d_loss: 0.4889 | g_loss: 3.2459
# Epoch [   22/   30] | d_loss: 0.3323 | g_loss: 3.0499
# Epoch [   22/   30] | d_loss: 0.3183 | g_loss: 3.5111
# Epoch [   22/   30] | d_loss: 0.2184 | g_loss: 2.6261
# Epoch [   22/   30] | d_loss: 0.4902 | g_loss: 3.4172
# Epoch [   22/   30] | d_loss: 0.2140 | g_loss: 2.7563
# Epoch [   22/   30] | d_loss: 0.1962 | g_loss: 2.4367
# Epoch [   22/   30] | d_loss: 0.7424 | g_loss: 4.5770
# Epoch [   22/   30] | d_loss: 0.1739 | g_loss: 3.9478
# Epoch [   22/   30] | d_loss: 0.3879 | g_loss: 2.4682
# Epoch [   22/   30] | d_loss: 0.3937 | g_loss: 2.5826
# Epoch [   22/   30] | d_loss: 0.3209 | g_loss: 2.0200
# Epoch [   22/   30] | d_loss: 0.4080 | g_loss: 3.5582
# Epoch [   22/   30] | d_loss: 0.2537 | g_loss: 2.3288
# Epoch [   22/   30] | d_loss: 0.3494 | g_loss: 2.9960
# Epoch [   23/   30] | d_loss: 0.3644 | g_loss: 2.9880
# Epoch [   23/   30] | d_loss: 0.4077 | g_loss: 1.4818
# Epoch [   23/   30] | d_loss: 0.1380 | g_loss: 3.2862
# Epoch [   23/   30] | d_loss: 0.1665 | g_loss: 4.1394
# Epoch [   23/   30] | d_loss: 0.5537 | g_loss: 1.0269
# Epoch [   23/   30] | d_loss: 0.6541 | g_loss: 1.8441
# Epoch [   23/   30] | d_loss: 0.3486 | g_loss: 1.7695
# Epoch [   23/   30] | d_loss: 0.3564 | g_loss: 1.5720
# Epoch [   23/   30] | d_loss: 0.4488 | g_loss: 4.4587
# Epoch [   23/   30] | d_loss: 0.2385 | g_loss: 3.3249
# Epoch [   23/   30] | d_loss: 0.5290 | g_loss: 4.8145
# Epoch [   23/   30] | d_loss: 0.2586 | g_loss: 3.1188
# Epoch [   23/   30] | d_loss: 0.2869 | g_loss: 5.1928
# Epoch [   23/   30] | d_loss: 0.6547 | g_loss: 3.4591
# Epoch [   23/   30] | d_loss: 0.2035 | g_loss: 4.4027
# Epoch [   24/   30] | d_loss: 0.2801 | g_loss: 2.5829
# Epoch [   24/   30] | d_loss: 0.2017 | g_loss: 3.5025
# Epoch [   24/   30] | d_loss: 0.1168 | g_loss: 4.8147
# Epoch [   24/   30] | d_loss: 0.1267 | g_loss: 3.7958
# Epoch [   24/   30] | d_loss: 0.2427 | g_loss: 3.9242
# Epoch [   24/   30] | d_loss: 0.3007 | g_loss: 3.0043
# Epoch [   24/   30] | d_loss: 0.3917 | g_loss: 1.9618
# Epoch [   24/   30] | d_loss: 0.6035 | g_loss: 1.8182
# Epoch [   24/   30] | d_loss: 0.2979 | g_loss: 2.2844
# Epoch [   24/   30] | d_loss: 3.1089 | g_loss: 6.8651
# Epoch [   24/   30] | d_loss: 0.4954 | g_loss: 2.2198
# Epoch [   24/   30] | d_loss: 0.3150 | g_loss: 3.2263
# Epoch [   24/   30] | d_loss: 0.3755 | g_loss: 3.2398
# Epoch [   24/   30] | d_loss: 0.2459 | g_loss: 3.8861
# Epoch [   24/   30] | d_loss: 0.3748 | g_loss: 2.3276
# Epoch [   25/   30] | d_loss: 0.3610 | g_loss: 3.3006
# Epoch [   25/   30] | d_loss: 0.2779 | g_loss: 3.0083
# Epoch [   25/   30] | d_loss: 0.5661 | g_loss: 3.8002
# Epoch [   25/   30] | d_loss: 0.7271 | g_loss: 2.8194
# Epoch [   25/   30] | d_loss: 0.3125 | g_loss: 2.8396
# Epoch [   25/   30] | d_loss: 0.6915 | g_loss: 1.7043
# Epoch [   25/   30] | d_loss: 0.1431 | g_loss: 1.4252
# Epoch [   25/   30] | d_loss: 0.2197 | g_loss: 2.8510
# Epoch [   25/   30] | d_loss: 0.4067 | g_loss: 2.0010
# Epoch [   25/   30] | d_loss: 0.2127 | g_loss: 3.0088
# Epoch [   25/   30] | d_loss: 0.6240 | g_loss: 2.8153
# Epoch [   25/   30] | d_loss: 0.3655 | g_loss: 4.1755
# Epoch [   25/   30] | d_loss: 0.2713 | g_loss: 3.5939
# Epoch [   25/   30] | d_loss: 0.2019 | g_loss: 2.5351
# Epoch [   25/   30] | d_loss: 1.0107 | g_loss: 6.1274
# Epoch [   26/   30] | d_loss: 0.5581 | g_loss: 3.8216
# Epoch [   26/   30] | d_loss: 0.2693 | g_loss: 2.0260
# Epoch [   26/   30] | d_loss: 0.1853 | g_loss: 3.9412
# Epoch [   26/   30] | d_loss: 0.3396 | g_loss: 3.1518
# Epoch [   26/   30] | d_loss: 0.1889 | g_loss: 3.6919
# Epoch [   26/   30] | d_loss: 0.6705 | g_loss: 1.9589
# Epoch [   26/   30] | d_loss: 0.7661 | g_loss: 2.3023
# Epoch [   26/   30] | d_loss: 0.2866 | g_loss: 3.7660
# Epoch [   26/   30] | d_loss: 0.4145 | g_loss: 2.3667
# Epoch [   26/   30] | d_loss: 0.2408 | g_loss: 3.8296
# Epoch [   26/   30] | d_loss: 0.2123 | g_loss: 3.2673
# Epoch [   26/   30] | d_loss: 0.3287 | g_loss: 1.9845
# Epoch [   26/   30] | d_loss: 0.1621 | g_loss: 3.6063
# Epoch [   26/   30] | d_loss: 0.1835 | g_loss: 2.8510
# Epoch [   26/   30] | d_loss: 0.3283 | g_loss: 2.1309
# Epoch [   27/   30] | d_loss: 0.2932 | g_loss: 2.7667
# Epoch [   27/   30] | d_loss: 0.1006 | g_loss: 4.1375
# Epoch [   27/   30] | d_loss: 0.2936 | g_loss: 3.7236
# Epoch [   27/   30] | d_loss: 0.3432 | g_loss: 2.8238
# Epoch [   27/   30] | d_loss: 0.2152 | g_loss: 0.9589
# Epoch [   27/   30] | d_loss: 0.3067 | g_loss: 3.5500
# Epoch [   27/   30] | d_loss: 0.2914 | g_loss: 2.2392
# Epoch [   27/   30] | d_loss: 0.3879 | g_loss: 2.8450
# Epoch [   27/   30] | d_loss: 0.4233 | g_loss: 3.3881
# Epoch [   27/   30] | d_loss: 0.4325 | g_loss: 1.7475
# Epoch [   27/   30] | d_loss: 0.3232 | g_loss: 3.5123
# Epoch [   27/   30] | d_loss: 0.6878 | g_loss: 3.4313
# Epoch [   27/   30] | d_loss: 0.3945 | g_loss: 4.3839
# Epoch [   27/   30] | d_loss: 0.1609 | g_loss: 3.7317
# Epoch [   27/   30] | d_loss: 0.2498 | g_loss: 2.7992
# Epoch [   28/   30] | d_loss: 0.1623 | g_loss: 2.7832
# Epoch [   28/   30] | d_loss: 0.1626 | g_loss: 2.8373
# Epoch [   28/   30] | d_loss: 0.2713 | g_loss: 2.2680
# Epoch [   28/   30] | d_loss: 0.5002 | g_loss: 3.4026
# Epoch [   28/   30] | d_loss: 0.4086 | g_loss: 2.2326
# Epoch [   28/   30] | d_loss: 0.2035 | g_loss: 4.2611
# Epoch [   28/   30] | d_loss: 0.2429 | g_loss: 2.0947
# Epoch [   28/   30] | d_loss: 0.3668 | g_loss: 3.1881
# Epoch [   28/   30] | d_loss: 0.2846 | g_loss: 1.9557
# Epoch [   28/   30] | d_loss: 0.2868 | g_loss: 2.4917
# Epoch [   28/   30] | d_loss: 0.2026 | g_loss: 2.3628
# Epoch [   28/   30] | d_loss: 1.1826 | g_loss: 1.5482
# Epoch [   28/   30] | d_loss: 0.8990 | g_loss: 3.7473
# Epoch [   28/   30] | d_loss: 0.3196 | g_loss: 4.6676
# Epoch [   28/   30] | d_loss: 0.1364 | g_loss: 2.7867
# Epoch [   29/   30] | d_loss: 0.1354 | g_loss: 3.3591
# Epoch [   29/   30] | d_loss: 0.1853 | g_loss: 3.3389
# Epoch [   29/   30] | d_loss: 0.1994 | g_loss: 3.3506
# Epoch [   29/   30] | d_loss: 0.1817 | g_loss: 2.8217
# Epoch [   29/   30] | d_loss: 0.3365 | g_loss: 1.9936
# Epoch [   29/   30] | d_loss: 0.1403 | g_loss: 3.7477
# Epoch [   29/   30] | d_loss: 0.2727 | g_loss: 1.6122
# Epoch [   29/   30] | d_loss: 0.1356 | g_loss: 3.5104
# Epoch [   29/   30] | d_loss: 0.1419 | g_loss: 3.7749
# Epoch [   29/   30] | d_loss: 0.1156 | g_loss: 4.5774
# Epoch [   29/   30] | d_loss: 0.2290 | g_loss: 2.9203
# Epoch [   29/   30] | d_loss: 0.4506 | g_loss: 2.1294
# Epoch [   29/   30] | d_loss: 0.3298 | g_loss: 1.5551
# Epoch [   29/   30] | d_loss: 0.7298 | g_loss: 4.5145
# Epoch [   29/   30] | d_loss: 0.2712 | g_loss: 3.2633
# Epoch [   30/   30] | d_loss: 0.5727 | g_loss: 4.2875
# Epoch [   30/   30] | d_loss: 0.1312 | g_loss: 2.8763
# Epoch [   30/   30] | d_loss: 0.2473 | g_loss: 2.7450
# Epoch [   30/   30] | d_loss: 0.1237 | g_loss: 3.2997
# Epoch [   30/   30] | d_loss: 0.2201 | g_loss: 2.5447
# Epoch [   30/   30] | d_loss: 0.9573 | g_loss: 3.9990
# Epoch [   30/   30] | d_loss: 0.1320 | g_loss: 4.1178
# Epoch [   30/   30] | d_loss: 0.3535 | g_loss: 3.8823
# Epoch [   30/   30] | d_loss: 0.2006 | g_loss: 4.4641
# Epoch [   30/   30] | d_loss: 0.5018 | g_loss: 1.9429
# Epoch [   30/   30] | d_loss: 0.1019 | g_loss: 3.9910
# Epoch [   30/   30] | d_loss: 0.3827 | g_loss: 4.1195
# Epoch [   30/   30] | d_loss: 0.0952 | g_loss: 5.6760
# Epoch [   30/   30] | d_loss: 0.3277 | g_loss: 1.6981
# Epoch [   30/   30] | d_loss: 0.1114 | g_loss: 2.9071

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
# - The biased dataset makes it hard for the generator to generalize to different colored faces
# - To models are low resolution, which makes it hard to add many convolutional layers - increasing the size of images along with the number of convolutional layers could allow the model to learn more unique features
# - Label smoothing could've been an option to optimize the model

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
